# %%
import pandas as pd
import numpy as np

# %%
plot_decision_regions(x_train,y_train.values,clf=clf,legend=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6f025b71a7eb> in <cell line: 0>()
# ----> 1 plot_decision_regions(x_train,y_train.values,clf=clf,legend=2)
#
# NameError: name 'plot_decision_regions' is not defined

# %%
df= pd.read_csv('/content/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
# Steps

# 0. Preprocess + EDA + Feature Selection
# 1. Extract input and output cols
# 2. Scale the values
# 3. Train test split
# 4. Train the model
# 5. Evaluate the model/model selection
# 6. Deploy the model

# %%
# Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df=df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
#EDA

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
x= df.iloc[:,0:2]
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
x.shape
# Out:
# (100, 2)

# %%
y= df.iloc[:,2:3]
y
# Out:
#     placement
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0
# ..        ...
# 95          0
# 96          0
# 97          1
# 98          1
# 99          1
#
# [100 rows x 1 columns]

# %%
y.shape
# Out:
# (100, 1)

# %%
# Train test split

# %%
from sklearn.model_selection import train_test_split
train_test_split(x,y,test_size=0.10)
# Out:
# [    cgpa     iq
#  23   4.7   87.0
#  1    5.9  106.0
#  33   6.0  149.0
#  94   4.7   52.0
#  42   7.6   89.0
#  ..   ...    ...
#  96   4.4   42.0
#  6    5.7  143.0
#  11   6.9  138.0
#  30   7.6  128.0
#  44   7.5   61.0
#
#  [90 rows x 2 columns],
#      cgpa     iq
#  86   5.1  128.0
#  47   5.2  161.0
#  14   6.1  103.0
#  58   8.0   79.0
#  70   6.3  127.0
#  90   7.3   86.0
#  78   6.1   81.0
#  12   5.4  139.0
#  40   4.9  134.0
#  54   6.4  141.0,
#      placement
#  23          0
#  1           0
#  33          0
#  94          0
#  42          1
#  ..        ...
#  96          0
#  6           0
#  11          1
#  30          1
#  44          1
#
#  [90 rows x 1 columns],
#      placement
#  86          0
#  47          0
#  14          0
#  58          1
#  70          1
#  90          1
#  78          0
#  12          0
#  40          0
#  54          1]

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.10)

# %%
x_train
# Out:
#     cgpa     iq
# 97   6.7  182.0
# 92   5.2  110.0
# 46   5.3  114.0
# 11   6.9  138.0
# 27   6.0  124.0
# ..   ...    ...
# 42   7.6   89.0
# 5    7.1   48.0
# 72   7.3  116.0
# 19   5.2  132.0
# 32   7.0  139.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
#     placement
# 97          1
# 92          0
# 46          0
# 11          1
# 27          1
# ..        ...
# 42          1
# 5           1
# 72          1
# 19          0
# 32          1
#
# [90 rows x 1 columns]

# %%
# Scale the values

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 0.66831519,  1.41111311],
#        [-0.66831519, -0.35960977],
#        [-0.5792065 , -0.26123628],
#        [ 0.84653258,  0.32900468],
#        [ 0.04455435, -0.01530254],
#        [-2.18316297,  2.66537515],
#        [ 0.5792065 , -0.11367604],
#        [ 0.40098912,  0.4027848 ],
#        [-1.7376195 , -0.6055435 ],
#        [ 0.04455435,  0.59953179],
#        [-0.93564127,  0.64871854],
#        [-1.38118473,  0.59953179],
#        [-0.84653258, -0.82688386],
#        [-0.22277173,  0.37819143],
#        [-2.36138035,  1.43570648],
#        [ 0.31188042, -0.53176338],
#        [-0.66831519, -0.85147724],
#        [-1.8267282 , -0.38420314],
#        [ 0.13366304,  0.18144444],
#        [-0.93564127,  0.74709203],
#        [-0.49009781, -0.43338989],
#        [ 1.02474996,  0.64871854],
#        [ 1.20296735,  0.30441131],
#        [ 1.29207604,  0.18144444],
#        [ 0.13366304, -0.53176338],
#        [ 0.31188042,  0.05847758],
#        [ 1.38118473,  0.82087215],
#        [-1.20296735,  0.52575167],
#        [ 0.13366304,  0.7716854 ],
#        [-0.93564127,  0.23063119],
#        [ 0.93564127, -0.31042302],
#        [-1.7376195 , -1.22037784],
#        [ 1.91583689,  1.01761914],
#        [-0.93564127,  1.75542034],
#        [ 0.49009781, -2.15492602],
#        [ 0.75742389, -0.85147724],
#        [-1.02474996,  1.09139926],
#        [ 0.84653258, -0.703917  ],
#        [ 0.75742389, -0.03989592],
#        [ 0.75742389,  0.4027848 ],
#        [ 0.93564127,  1.2389595 ],
#        [-1.02474996,  0.94383902],
#        [ 1.20296735, -0.94985073],
#        [ 0.49009781,  0.1322577 ],
#        [-0.49009781,  0.35359806],
#        [-1.11385866, -1.78602542],
#        [-0.93564127, -0.11367604],
#        [ 0.5792065 ,  0.32900468],
#        [ 1.64851081, -0.26123628],
#        [ 0.84653258,  0.35359806],
#        [-0.5792065 , -0.08908266],
#        [-1.11385866, -0.08908266],
#        [-0.22277173,  1.09139926],
#        [ 1.47029343,  0.08307095],
#        [ 2.09405427,  1.06680588],
#        [-1.47029343,  1.85379383],
#        [-1.02474996, -0.31042302],
#        [-0.75742389,  1.26355287],
#        [-1.38118473, -2.03195916],
#        [-0.13366304,  1.01761914],
#        [ 1.8267282 , -1.12200434],
#        [ 0.31188042,  0.08307095],
#        [ 0.93564127, -1.49090494],
#        [-0.04455435, -0.45798326],
#        [-0.66831519,  0.89465227],
#        [-0.66831519,  2.44403479],
#        [ 0.04455435, -1.4417182 ],
#        [-0.75742389,  0.08307095],
#        [ 0.75742389, -0.31042302],
#        [-0.84653258, -0.16286278],
#        [-0.22277173,  0.45197155],
#        [-0.93564127, -1.56468506],
#        [ 0.49009781,  0.8700589 ],
#        [ 0.04455435, -1.95817904],
#        [ 0.93564127,  1.82920046],
#        [ 0.66831519,  0.72249866],
#        [ 0.49009781, -0.85147724],
#        [ 1.38118473, -1.56468506],
#        [-0.75742389, -1.4417182 ],
#        [-0.49009781,  0.25522456],
#        [-0.22277173,  0.18144444],
#        [ 0.22277173, -0.28582965],
#        [ 0.13366304, -1.0728176 ],
#        [-1.11385866, -0.92525736],
#        [ 1.20296735, -1.83521217],
#        [ 1.47029343, -0.87607061],
#        [ 1.02474996, -1.88439892],
#        [ 1.20296735, -0.21204953],
#        [-0.66831519,  0.18144444],
#        [ 0.93564127,  0.35359806]])

# %%
x_test = scaler.fit_transform(x_test)

# %%
x_test
# Out:
# array([[-1.12462004, -1.79020979],
#        [ 0.03307706,  0.06293706],
#        [ 1.76962271,  0.2027972 ],
#        [-0.21500089, -1.72027972],
#        [-0.79384944, -0.00699301],
#        [-0.29769354, -0.42657343],
#        [ 1.43885211,  1.21678322],
#        [ 0.94269621,  0.55244755],
#        [-0.46307884,  0.97202797],
#        [-1.29000534,  0.93706294]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model training
clf.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_pred = clf.predict(x_test)

# %%
y_test
# Out:
#     placement
# 7           0
# 13          1
# 69          1
# 56          0
# 41          0
# 62          0
# 37          1
# 83          1
# 4           0
# 51          0

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train, y_train.values.squeeze(), clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('placement_predection.pkl','wb'))
